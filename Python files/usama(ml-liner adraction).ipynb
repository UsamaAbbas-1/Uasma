# %%
import pandas as pd
df = pd.read_excel("ml-regress.xlsx")
df.head(15)
# Out:
#      age  distance  experiemnce  salary
# 0   31.0      80.0          2.0   38526
# 1   32.0      70.0          1.6   31256
# 2   32.5      70.5          1.1   31478
# 3   33.0      84.5          2.3   40259
# 4   33.5      23.6          5.0   45216
# 5   34.0      24.6          6.4   46231
# 6   34.6      66.2          5.2   45236
# 7   35.0      66.0          6.2   21358
# 8   35.9      65.0          7.2   25856
# 9   35.3      63.0          5.2   54684
# 10  35.7      64.0          4.9   84625
# 11  36.0      69.0          2.3   55929
# 12  36.2      71.0          2.4   56132
# 13  36.7      20.0          2.6   65468
# 14  36.9      54.0          1.5   54822

# %%
x = df[["experiemnce"]]
y = df["salary"]

# %%
x.head(5)
# Out:
#    experiemnce
# 0          2.0
# 1          1.6
# 2          1.1
# 3          2.3
# 4          5.0

# %%
y.head(5)
# Out:
# 0    38526
# 1    31256
# 2    31478
# 3    40259
# 4    45216
# Name: salary, dtype: int64

# %% [markdown]
# ### spliting

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,)

# %%
x
# Out:
#     experiemnce
# 0           2.0
# 1           1.6
# 2           1.1
# 3           2.3
# 4           5.0
# 5           6.4
# 6           5.2
# 7           6.2
# 8           7.2
# 9           5.2
# 10          4.9
# 11          2.3
# 12          2.4
# 13          2.6
# 14          1.5
# 15          1.4
# 16          1.6
# 17          1.8
# 18          2.1
# 19          2.5
# 20          2.9
# 21          2.7
# 22          3.4
# 23          3.6
# 24          3.5
# 25          3.4
# 26          3.9
# 27          4.2
# 28          1.7

# %% [markdown]
# ### fit model

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression().fit(x_train,y_train)
model
# Out:
# LinearRegression()

# %% [markdown]
# ### ploting

# %%
import matplotlib.pyplot as plt
plt.scatter(x_train,y_train)
plt.plot(x_train, model.predict(x_train),color="Green")
plt.xlabel("years")
plt.ylabel("salary")
plt.title("train plot")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Out:
#     experiemnce
# 0           2.0
# 1           1.6
# 2           1.1
# 3           2.3
# 4           5.0
# 5           6.4
# 6           5.2
# 7           6.2
# 8           7.2
# 9           5.2
# 10          4.9
# 11          2.3
# 12          2.4
# 13          2.6
# 14          1.5
# 15          1.4
# 16          1.6
# 17          1.8
# 18          2.1
# 19          2.5
# 20          2.9
# 21          2.7
# 22          3.4
# 23          3.6
# 24          3.5
# 25          3.4
# 26          3.9
# 27          4.2
# 28          1.7

# %%
plt.scatter(x_train,y_train)
plt.plot(x_train, model.predict(x_train),color="Red")
plt.xlabel("years")
plt.ylabel("salary")
plt.title("train plot")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x
# Out:
#     experiemnce
# 0           2.0
# 1           1.6
# 2           1.1
# 3           2.3
# 4           5.0
# 5           6.4
# 6           5.2
# 7           6.2
# 8           7.2
# 9           5.2
# 10          4.9
# 11          2.3
# 12          2.4
# 13          2.6
# 14          1.5
# 15          1.4
# 16          1.6
# 17          1.8
# 18          2.1
# 19          2.5
# 20          2.9
# 21          2.7
# 22          3.4
# 23          3.6
# 24          3.5
# 25          3.4
# 26          3.9
# 27          4.2
# 28          1.7
